# %% [markdown]
# #HW 1
#
# ##In this homework, you will be using concepts from the SQL lecture and APIs to explroe a dataset and make some basic queries.

# %%
#%reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
# Import Pandas, Numpy, Matplotlib, and Sqlite3
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sqlite3
from pprint import pprint

# This enables inline Plots
# %matplotlib inline

# Limit rows displayed in notebook
pd.set_option('display.max_rows', 10)
pd.set_option('display.precision', 2)

# %% [markdown]
# #### 1. Connect to the SF.Gov API and pull data from the 311 Table
# https://data.sfgov.org/City-Infrastructure/Case-Data-from-San-Francisco-311-SF311-/vw6y-z8j6
#
# * 311 data contains over 1.1 Million rows in total. For this exercise, we are only looking to pull the FIRST 1000 rows
#
# Note: To get more data than 1000 rows, you may need to sign up for an app token to avoid throttling limits
# http://dev.socrata.com/foundry/#/data.sfgov.org/vw6y-z8j6
#
# We don't need this for the exercise, but something to keep in mind as you work with external APIs

# %%
# This will get you the first 1000 rows to get started with the rest of the questions
import json
import urllib

url = "https://data.sfgov.org/resource/vw6y-z8j6.json"
data = json.load(urllib.urlopen(url))

# %%
#YOUR CODE HERE - Display the first element (row) in data
df_data = pd.DataFrame(data)

print("First element of the list version:")
pprint(data[1])

# The first element in the rows is a NaN row:
print("\nFirst element after of the panel data version:")
df_data[:1]

print("\nFirst element after after dropping NaN:")
df_data_noNaN = df_data.dropna()
df_data_noNaN[:1]
# Out:
# First element of the list version:
# {}
#
# First element after of the panel data version:
#
# First element after after dropping NaN:
#                                     address  case_id      category  \
# 264  201 SPEAR ST, SAN FRANCISCO, CA, 94105  4427946  Sewer Issues
#
#                   closed                                          media_url  \
# 264  2015-01-26T07:57:25  {u'url': u'http://mobile311.sfgov.org/media/sa...
#
#            neighborhood               opened  \
# 264  Financial District  2015-01-26T00:07:41
#
#                                                  point request_details  \
# 264  {u'latitude': u'37.79105274081', u'needs_recod...       On_street
#
#     request_type responsible_agency   source  status supervisor_district  \
# 264     Flooding      PUC Sewer Ops  Open311  Closed                   6
#
#                  updated
# 264  2015-01-26T07:57:25

# %% [markdown]
# #### 2. How many elements are there in the JSON file?

# %%
#YOUR CODE HERE
n_elements = len(df_data)
print("If each row is an element there are " + str(n_elements) + " elements\n")


# If an element is each value:
n_elements = df_data.shape
n_elements = n_elements[0] * n_elements[1]

print("If each value is an element there are " + str(n_elements) + " elements")
# Out:
# If each row is an element there are 1000 elements
#
# If each value is an element there are 15000 elements

# %% [markdown]
# #### Display the length of the JSON object and display the elements contained in one of the items of the JSON file?

# %%
#YOUR CODE HERE

# Here are the elements
print("The length of the JSON Object is: " + str(len(data)) + "\n")


print("The elements in contained in the 500th elemnt are: \n")
pprint(data[500])
# Out:
# The length of the JSON Object is: 1000
#
# The elements in contained in the 500th elemnt are:
#
# {u'address': u'Intersection of 7TH ST and TOWNSEND ST',
#  u'case_id': u'4426898',
#  u'category': u'Street and Sidewalk Cleaning',
#  u'closed': u'2015-01-25T23:10:44',
#  u'neighborhood': u'South of Market',
#  u'opened': u'2015-01-25T14:15:38',
#  u'point': {u'latitude': u'37.7718171412752',
#             u'longitude': u'-122.401656775589',
#             u'needs_recoding': False},
#  u'request_details': u'Encampment Cleanup',
#  u'request_type': u'Illegal Encampment',
#  u'responsible_agency': u'DPW Ops Queue',
#  u'source': u'Voice In',
#  u'status': u'Closed',
#  u'supervisor_district': u'6',
#  u'updated': u'2015-01-25T23:10:44'}

# %% [markdown]
# ####3. Use Pandas "Read JSON" functionality to turn the 311 data into a Pandas Dataframe and display the first 20 rows

# %%
#YOUR CODE HERE

# Use Pandas "Read JSON" functionality to turn the 311 data into a Pandas Dataframe:
pd_data = pd.read_json(url)

# Display the first 20 rows in the dataframe:
print("\n The first 20 rows in the dataframe:")
pd_data[:500]
# Out:
#  The first 20 rows in the dataframe:
#                                        address  case_id  \
# 0                                          NaN      NaN
# 1                                          NaN      NaN
# 2                                          NaN      NaN
# 3                                          NaN      NaN
# 4                                          NaN      NaN
# ..                                         ...      ...
# 495      270 14TH ST, SAN FRANCISCO, CA, 94103  4426914
# 496  211 DENSLOWE DR, SAN FRANCISCO, CA, 94132  4426912
# 497     Intersection of 19TH ST and MISSION ST  4426905
# 498    Intersection of 11TH ST and HARRISON ST  4426904
# 499     210 16TH AVE, SAN FRANCISCO, CA, 94118  4426899
#
#                          category               closed media_url  \
# 0                             NaN                  NaN       NaN
# 1                             NaN                  NaN       NaN
# 2                             NaN                  NaN       NaN
# 3                             NaN                  NaN       NaN
# 4                             NaN                  NaN       NaN
# ..                            ...                  ...       ...
# 495  Street and Sidewalk Cleaning  2015-01-25T22:21:24       NaN
# 496                  Sewer Issues  2015-01-26T08:22:34       NaN
# 497                 MUNI Feedback                  NaN       NaN
# 498                 MUNI Feedback                  NaN       NaN
# 499  Street and Sidewalk Cleaning  2015-01-25T14:46:29       NaN
#
#         neighborhood               opened  \
# 0                NaN                  NaN
# 1                NaN                  NaN
# 2                NaN                  NaN
# 3                NaN                  NaN
# 4                NaN                  NaN
# ..               ...                  ...
# 495          Mission  2015-01-25T14:21:35
# 496        Lakeshore  2015-01-25T14:20:15
# 497          Mission  2015-01-25T14:17:21
# 498  South of Market  2015-01-25T14:17:10
# 499   Inner Richmond  2015-01-25T14:16:00
#
#                                                  point  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 495  {u'latitude': u'37.768554609', u'needs_recodin...
# 496  {u'latitude': u'37.720979781354', u'needs_reco...
# 497  {u'latitude': u'37.7602354682392', u'needs_rec...
# 498  {u'latitude': u'37.7706298096818', u'needs_rec...
# 499  {u'latitude': u'37.784095418398', u'needs_reco...
#
#                                  request_details  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# ..                                           ...
# 495                          Other Loose Garbage
# 496                          Outofsewervent4inch
# 497                   806_Muni_Rules_Regulations
# 498  107_Fall_Boarding_On_Board_Alighting_Injury
# 499                                    Furniture
#
#                         request_type  responsible_agency    source  status  \
# 0                                NaN                 NaN       NaN     NaN
# 1                                NaN                 NaN       NaN     NaN
# 2                                NaN                 NaN       NaN     NaN
# 3                                NaN                 NaN       NaN     NaN
# 4                                NaN                 NaN       NaN     NaN
# ..                               ...                 ...       ...     ...
# 495                 General Cleaning       DPW Ops Queue  Voice In  Closed
# 496                   Sewage_back_up       PUC Sewer Ops  Voice In  Closed
# 497    MUNI - Services_Miscellaneous     MUNI Work Queue  Voice In    Open
# 498  MUNI - Conduct_Unsafe_Operation     MUNI Work Queue  Voice In    Open
# 499                      Bulky Items  Recology_Abandoned  Voice In  Closed
#
#      supervisor_district              updated
# 0                    NaN                  NaN
# 1                    NaN                  NaN
# 2                    NaN                  NaN
# 3                    NaN                  NaN
# 4                    NaN                  NaN
# ..                   ...                  ...
# 495                    9  2015-01-25T22:21:24
# 496                    7  2015-01-26T08:22:34
# 497                    9  2015-01-25T14:22:04
# 498                    6  2015-01-25T14:37:41
# 499                    1  2015-01-25T14:46:29
#
# [500 rows x 15 columns]

# %% [markdown]
# ####4. How many missing values do we have?

# %%
#YOUR CODE HERE

# Each column has a different number of missing values, which can be observed here:
n_nan = np.sum(pd.isnull(pd_data))
print("Number of missing values for each feature: \n")
print(n_nan)

# The total number of missing values is:
n_nan = n_nan * 1;
n_nan = np.sum(n_nan[:])
n_nan = np.sum(n_nan)

print("The number of missing values is: " + str(n_nan))
# Out:
# Number of missing values for each feature:
#
# address     257
# case_id     257
# category    257
# ...
# status                 257
# supervisor_district    257
# updated                257
# Length: 15, dtype: int64
# The number of missing values is: 4695

# %% [markdown]
# ####5. Drop the "point" feature from the dataframe - its a dictionary, which is unsupported in a flat database

# %%
#YOUR CODE HERE

# read the column names
print("Original feature (i.e. column names):")
print(pd_data.columns)

# read the column names again (should be without 'point')
print("\nUpdated feature (i.e. column names):")
pd_data.drop('point',inplace=True,axis=1)


# re-index the dataframe:
print(pd_data.columns)
# Out:
# Original feature (i.e. column names):
# Index([u'address', u'case_id', u'category', u'closed', u'media_url', u'neighborhood', u'opened', u'point', u'request_details', u'request_type', u'responsible_agency', u'source', u'status', u'supervisor_district', u'updated'], dtype='object')
#
# Updated feature (i.e. column names):
# Index([u'address', u'case_id', u'category', u'closed', u'media_url', u'neighborhood', u'opened', u'request_details', u'request_type', u'responsible_agency', u'source', u'status', u'supervisor_district', u'updated'], dtype='object')

# %% [markdown]
# ####5. Turn the 311 data into a database. You can use the pandas read_sql command (example [here)]('http://bit.ly/1EoP81v') or the db package from yHat to do this.

# %%
#YOUR CODE HERE

# Set-Up variables:
df_name = 'tab311';

df_sql = pd.read_json(url)
df_sql.drop('point',inplace=True,axis=1)
df_sql.drop('media_url',inplace=True,axis=1)
pprint(df_sql.columns)

## Create the connection & write to connection:
con = sqlite3.connect('crntConnect')
sql_db = df_sql.to_sql(name = df_name, con = con, if_exists='replace')
# Out:
# Index([u'address', u'case_id', u'category', u'closed', u'neighborhood', u'opened', u'request_details', u'request_type', u'responsible_agency', u'source', u'status', u'supervisor_district', u'updated'], dtype='object')

# %% [markdown]
# ###### 6. Display the first 5 rows of the DB

# %%
#YOUR CODE HERE
# con = sqlite3.connect(url_sql)

df = pd.read_sql("SELECT * from " + df_name , con, index_col='index')
print("The first 5 (unsorted) rows are: \n")
df.head(5)

print("The first 5 rows after dropping NaN are: \n")
df = df.dropna()
print(df.head(5))
# Out:
# The first 5 (unsorted) rows are:
#
# The first 5 rows after dropping NaN are:
#
#                                              address  case_id  \
# index
# 258           Intersection of 32ND AVE and FULTON ST  4427993
# 260        Intersection of BACHE ST and CRESCENT AVE  4427977
# 262    1263 LEAVENWORTH ST, SAN FRANCISCO, CA, 94109  4427971
# 263           34 CHURCH ST, SAN FRANCISCO, CA, 94117  4427947
# 264           201 SPEAR ST, SAN FRANCISCO, CA, 94105  4427946
#
#                            category               closed        neighborhood  \
# index
# 258    Street and Sidewalk Cleaning  2015-01-26T12:15:28      Outer Richmond
# 260    Street and Sidewalk Cleaning  2015-01-26T11:28:55      Bernal Heights
# 262    Residential Building Request  2015-01-26T13:32:48            Nob Hill
# 263    Street and Sidewalk Cleaning  2015-01-26T09:02:28    Western Addition
# 264                    Sewer Issues  2015-01-26T07:57:25  Financial District
#
#                     opened                   request_details  \
# index
# 258    2015-01-26T04:59:10               Other Loose Garbage
# 260    2015-01-26T02:03:09                      Refrigerator
# 262    2015-01-26T01:03:50  Noise_Caused_by_Building_Systems
# 263    2015-01-26T00:07:45               Other Loose Garbage
# 264    2015-01-26T00:07:41                         On_street
#
#                                       request_type  \
# index
# 258                               General Cleaning
# 260                                    Bulky Items
# 262    Building - Noise_Caused_by_Building_Systems
# 263                               General Cleaning
# 264                                       Flooding
#
#                    responsible_agency            source  status  \
# index
# 258                Recology_Abandoned          Voice In  Closed
# 260                Recology_Abandoned          Voice In  Closed
# 262    DPH - Environmental Health - G  Web Self Service  Closed
# 263                     DPW Ops Queue           Open311  Closed
# 264                     PUC Sewer Ops           Open311  Closed
#
#        supervisor_district              updated
# index
# 258                      1  2015-01-26T12:15:28
# 260                      9  2015-01-26T11:28:55
# 262                      3  2015-01-26T13:32:48
# 263                      8  2015-01-26T09:02:28
# 264                      6  2015-01-26T07:57:25

# %% [markdown]
# ####7. Show 10 of the sidewalk cleanings in the Haight Ashbury neighborhood

# %%
#YOUR CODE HERE
df_ha = pd.read_sql("SELECT * from " + df_name + " WHERE neighborhood = 'Haight Ashbury' AND category = 'Street and Sidewalk Cleaning'" , con)

# Display the results:
print("\nThere are only " + str(df_ha.shape[0]) + " requests in the Haight Ashbury neighborhood" )
df_ha.head(10)
# Out:
# There are only 3 requests in the Haight Ashbury neighborhood
#    index                                     address  case_id  \
# 0    865    635 ASHBURY ST, SAN FRANCISCO, CA, 94117  4425326
# 1    927  Intersection of DOWNEY ST and FREDERICK ST  4425050
# 2    944      Intersection of CARL ST and STANYAN ST  4424823
#
#                        category               closed    neighborhood  \
# 0  Street and Sidewalk Cleaning                 None  Haight Ashbury
# 1  Street and Sidewalk Cleaning  2015-01-25T10:00:53  Haight Ashbury
# 2  Street and Sidewalk Cleaning  2015-01-26T21:14:02  Haight Ashbury
#
#                 opened      request_details      request_type  \
# 0  2015-01-24T17:26:22  Other Loose Garbage  General Cleaning
# 1  2015-01-24T15:50:57  Other Loose Garbage  General Cleaning
# 2  2015-01-24T14:46:37  Other Loose Garbage  General Cleaning
#
#   responsible_agency    source  status  supervisor_district  \
# 0      DPW Ops Queue  Voice In    Open                    5
# 1      DPW Ops Queue  Voice In  Closed                    5
# 2      DPW Ops Queue  Voice In  Closed                    5
#
#                updated
# 0  2015-01-25T06:43:37
# 1  2015-01-25T10:00:53
# 2  2015-01-26T21:14:02

# %% [markdown]
# ####8. Which type of complaint was most common?

# %%
#YOUR CODE HERE

# Run the query for question 8:    
df_q8 = pd.read_sql("SELECT request_type, COUNT(request_type) as countType from " + df_name + " GROUP BY request_type ORDER BY countType DESC", con)

# Print the answer
print("The most common complaint type was '" + df_q8['request_type'][0] + "' with " + str(df_q8['countType'][0]) + " complaints")
# Out:
# The most common complaint type was 'General Cleaning' with 151 complaints

# %% [markdown]
# ####9. Are there any neighborhoods where sidewalk cleaning requests aren't the most common?

# %%
#YOUR CODE HERE

# Grab initial sequal query:
df_q9 = pd.read_sql("SELECT neighborhood, category, COUNT(*) as countType from " + df_name + " GROUP BY neighborhood, category  ORDER BY countType DESC", con)
df_q9 = df_q9.dropna()

# Get the list of neighborhoods
list_names = pd.unique(df_q9['neighborhood'])

# Make a list of most common complain in each hood:
hood_list = pd.DataFrame(columns=df_q9.columns)
for ii in range(len(list_names)):
    tempName = pd.DataFrame(df_q9[df_q9['neighborhood']==str(list_names[ii])])
    hood_list = hood_list.append(tempName.iloc[0])
    
# Make a variable where the most common complain is not 'Street and Sidewalk Cleaning':
final_list = pd.DataFrame(columns=df_q9.columns)
for ii in range(len(list_names)):
    xName = hood_list.iloc[ii]
    if 'Street and Sidewalk Cleaning' != str(xName['category']):
        final_list = final_list.append(hood_list.iloc[ii])
    
# Print the results for the solution    
print("The following neighborhoods do not have 'Street and Sidewalk Cleaning' as their main complaint \n")
print(final_list)
# Out:
# The following neighborhoods do not have 'Street and Sidewalk Cleaning' as their main complaint
#
#             neighborhood                  category  countType
# 18        Bernal Heights         Abandoned Vehicle          7
# 24            Noe Valley              Sewer Issues          6
# 25          Potrero Hill             SFHA Requests          6
# 29      Golden Gate Park     Rec and Park Requests          5
# 30            Ocean View  Graffiti Public Property          5
# ..                   ...                       ...        ...
# 124             Seacliff          General Requests          2
# 158            Glen Park               Sign Repair          1
# 167            Lakeshore          General Requests          1
# 220  Treasure Island/YBI         Abandoned Vehicle          1
# 221           Twin Peaks  Graffiti Public Property          1
#
# [22 rows x 3 columns]

# %%
## Clean sequal query:
#df_q9 = pd.read_sql("SELECT neighborhood, category, COUNT(*) as countType from " + df_name + " GROUP BY neighborhood, category  ORDER BY countType DESC", con)
#df_q9 = df_q9.dropna()
#pd.DataFrame.to_csv(df_q9, path_or_buf = 'q9_initial_query.csv')
#pprint(df_q9)

# %%
## Get the list of neighborhoods
#list_names = pd.unique(df_q9['neighborhood'])
#print(list_names)

# %%
## Make a list of most common complain in each hood:
#hood_list = pd.DataFrame(columns=df_q9.columns)
#for ii in range(len(list_names)):
#    tempName = pd.DataFrame(df_q9[df_q9['neighborhood']==str(list_names[ii])])
#    hood_list = hood_list.append(tempName.iloc[0])
    
#print(hood_list)

# %%
## Print names that don't start
#final_list = pd.DataFrame(columns=df_q9.columns)
#for ii in range(len(list_names)):
#    xName = hood_list.iloc[ii]
#    if 'Street and Sidewalk Cleaning' != str(xName['category']):
#        final_list = final_list.append(hood_list.iloc[ii])
#    
#print("The following neighborhoods do not have 'Street and Sidewalk Cleaning' as their main complaint \n")
#print(final_list)
#pd.DataFrame.to_csv(final_list, 'Final_list.csv')

# %% [markdown]
# ####BONUS: Come up with your own query! Challenge your fellow classmates by posting your query on HipChat.

# %%
#YOUR CODE HERE
